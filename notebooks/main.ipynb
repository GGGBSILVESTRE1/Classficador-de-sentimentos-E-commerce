# %%
import pandas as pd

from src.config import SAMPLE_REVIEWS_PATH



df_sample = pd.read_parquet(SAMPLE_REVIEWS_PATH)
df_sample.head()
# Out:
#                                               review  score  \
# 0  Super leve, dinâmico e fácil de manusear...per...      4
# 1  Muito bom, ótima qualidade, tem vvarias funçõe...      5
# 2  Ótimo preço Qualidade entregue antes do prazo ...      5
# 3  Produto bom e cheiroso acabei com os piolhos d...      4
# 4  Bom por ser 3 em 1,com disparo de fotos e luze...      4
#
#                                         product_name     source
# 0  Smartphone Samsung Galaxy J1 Mini Dual Chip An...        b2w
# 1  Tablet Samsung Galaxy Tab A T280 8GB Wi-Fi Tel...        b2w
# 2  Torneira Misturador De Cozinha Cromada Cairo D...        b2w
# 3                                               <NA>  octaprice
# 4                                               <NA>    buscape
